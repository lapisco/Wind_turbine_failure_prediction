# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
import os
import warnings
warnings.filterwarnings('ignore')

DATAFOLDER = os.path.join('..', 'data', 'csv')
DATAS = {'FOURIER': 'v000_SCIG_SC_SENSORC_FOURIER_010'}

SEED = 6969
TEST_SIZE = 0.1

# %% [markdown]
# # Load data

# %%
data = pd.read_csv(os.path.join(DATAFOLDER, DATAS['FOURIER'] + '.csv'))
data.sort_values(by='Class', inplace=True)
data.head()
# Out:
#      idx  fx1_R   fx0d5_R   fx1d5_R   fx2d5_R     fx3_R     fx5_R     fx7_R  \
# 0      1    1.0  0.007299  0.006626  0.000968  0.023378  0.023553  0.006339
# 157  158    1.0  0.006656  0.001758  0.000721  0.011023  0.013732  0.007035
# 158  159    1.0  0.007376  0.002492  0.001088  0.014117  0.014365  0.007669
# 159  160    1.0  0.011259  0.005321  0.001449  0.009652  0.022458  0.009151
# 160  161    1.0  0.009387  0.001955  0.000894  0.008107  0.013776  0.007865
#
#      fx1_S   fx0d5_S  ...     fx7_T  Freq_Rated  Freq_Gen  CC_bus  Power  \
# 0      1.0  0.007219  ...  0.006059        45.0     43.85     369   0.57
# 157    1.0  0.006686  ...  0.006961        55.0     54.41     290   0.23
# 158    1.0  0.007364  ...  0.007532        55.0     54.43     282   0.21
# 159    1.0  0.011178  ...  0.008889        55.0     54.45     273   0.20
# 160    1.0  0.009337  ...  0.007708        55.0     54.47     261   0.18
#
#       I_R_rms   I_S_rms   I_T_rms  Load  Class
# 0    2.906343  2.920356  2.986445     0      1
# 157  1.748649  1.742790  1.774084     0      1
# 158  1.675155  1.672618  1.700071     0      1
# 159  1.594791  1.595716  1.617615     0      1
# 160  1.512513  1.517633  1.533782     0      1
#
# [5 rows x 31 columns]

# %%
for feature_set in DATAS.keys():
    data = pd.read_csv(os.path.join(DATAFOLDER, DATAS[feature_set] + '.csv'))

    labels = data['Class']
    features = data

    X = features.values
    y = labels.values

    sss = StratifiedShuffleSplit(n_splits=1, test_size=TEST_SIZE, random_state=SEED)
    for train_index, test_index in sss.split(features, labels):
        print("TRAIN size:", len(train_index), "TEST size:", len(test_index))
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        pd.DataFrame(X_train, columns=features.columns).to_csv(os.path.join(DATAFOLDER, DATAS[feature_set] + '_chunk_{}.csv'.format(90)), index=False)
        pd.DataFrame(y_train, columns=['Class']).to_csv(os.path.join(DATAFOLDER, DATAS[feature_set] + '_labels_chunk_{}.csv'.format(90)), index=False)

        pd.DataFrame(X_test, columns=features.columns).to_csv(os.path.join(DATAFOLDER, DATAS[feature_set] + '_chunk_{}.csv'.format(int(TEST_SIZE*100))), index=False)
        pd.DataFrame(y_test, columns=['Class']).to_csv(os.path.join(DATAFOLDER, DATAS[feature_set] + '_labels_chunk_{}.csv'.format(int(TEST_SIZE*100))), index=False)
# Out:
# TRAIN size: 1220 TEST size: 136

# %% [markdown]
# Now, the held out test set has been taken away.
